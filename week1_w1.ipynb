# %%
var = 20
var2 = 30
gun = "pazartesi"
print(var)
print(var2)
print(gun)
type(var)
type(gun)
# Out:
# 20
# 30
# pazartesi
# str

# %%
#List

var1 = 10
var2 = 20
var3 = 30
list_int = [10,20,30,40]
type(list_int)
# Out:
# list

# %%
list_int[0]
# Out:
# 10

# %%
#Last element of the list
list_int[-1]
# Out:
# 40

# %%
# element from index 0 first 3
list_int[0:3]
# Out:
# [10, 20, 30]

# %%
#add at list 
list_int.append(30)
print(list_int)
# Out:
# [10, 20, 30, 40, 30]

# %%
list_int.remove(30)

# %%
print(list_int)
# Out:
# [10, 20, 40, 30]

# %%
list_int.reverse()
print(list_int)
# Out:
# [30, 40, 20, 10]

# %%
list_int.sort()
print(list_int)
# Out:
# [10, 20, 30, 40]

# %%
max = 10
for each in list_int:
    if(each > max ):
        max = each
    else:
        continue
        
print(max)
# Out:
# 40

# %%
i = 0
while(i<5):
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def cember_cevre(r,pi=3.14): # Pi is a default value
    result = 2*pi*r
    return result

cember_cevre(2)
# Out:
# 12.56

# %%
def hesapla(x):
    result = x * x
    return result

sonuc = hesapla(2)
print(sonuc)

#Another way
sonuc2 = lambda x: x*x
print(sonuc2(2))
# Out:
# 4
# 4

# %%
dictionary = {"ghiath":24,"ilyas":24,"omer":22}
print(dictionary)
# Out:
# {'ghiath': 24, 'ilyas': 24, 'omer': 22}

# %%
type(dictionary)
# Out:
# dict

# %%
dictionary.keys()
# Out:
# dict_keys(['ghiath', 'ilyas', 'omer'])

# %%
dictionary.values()
# Out:
# dict_values([24, 24, 22])

# %%
keys = dictionary.keys()
if "halit" in keys:
    print("The name is exist!")
else:
    print("The name is not exist!")
# Out:
# The name is not exist!

# %%
keys = dictionary.keys()
if "tntn" in keys:
    print("The name is exist!")
else:
    print("The name is not exist!")
# Out:
# The name is not exist!
