# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/Users/gaithalmadani/university/2.dönem/Machine Learning/lab/linear_regression_dataset.csv")

# %%
df
# Out:
#    deneyim;maas
# 0      0.5;2500
# 1        0;2250
# 2        1;2750
# 3        5;8000
# 4        8;9000
# 5        4;6900
# 6      15;20000
# 7        7;8500
# 8        3;6000
# 9        2;3500
# 10     12;15000
# 11     10;13000
# 12     14;18000
# 13       6;7500

# %%
df=pd.read_csv("/Users/gaithalmadani/university/2.dönem/Machine Learning/lab/linear_regression_dataset.csv",sep=";")

# %%
df
# Out:
#     deneyim   maas
# 0       0.5   2500
# 1       0.0   2250
# 2       1.0   2750
# 3       5.0   8000
# 4       8.0   9000
# 5       4.0   6900
# 6      15.0  20000
# 7       7.0   8500
# 8       3.0   6000
# 9       2.0   3500
# 10     12.0  15000
# 11     10.0  13000
# 12     14.0  18000
# 13      6.0   7500

# %%
plt.scatter(df.deneyim,df.maas)
plt.xlabel("experience")
plt.ylabel("salary")
plt.show()

# %%
x=df.deneyim.values

# %%
x.shape
# Out:
# (14,)

# %%
x=df.deneyim.values.reshape(-1,1)
y=df.maas.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
linear_reg=LinearRegression()
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
b0=linear_reg.predict([[0]])

# %%
b0=linear_reg.intercept_
print(b0)
# Out:
# [1663.89519747]

# %%
b1=linear_reg.coef_
print(b1)
# Out:
# [[1138.34819698]]

# %% [markdown]
# Y=BO+B1*X

# %%
new_salary=1663+1138*11
print(new_salary)
# Out:
# 14181

# %%
b11=linear_reg.predict([[11]])
print(b11)
# Out:
# [[14185.72536421]]

# %%
y_head=linear_reg.predict(x)
plt.plot(x,y_head,color="red")
plt.scatter(x,y)
plt.show()

# %%
from sklearn.metrics import r2_score
print("r square score",r2_score(y,y_head))
# Out:
# r square score 0.9775283164949903
